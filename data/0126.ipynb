# %% [markdown]
# # Homework 2
#
# The goal of this Homework is to write Python code to answer each of the questions below. You should be able to answer these questions using Pandas only. You should not need to import any other packages. You should not use Excel or any other means to answer these questions. **Since questions have subquestions, it would be helpful if you use comments to clearly indicate which question you are answering**.
#
# ## Introduction
# The Centers for Medicare & Medicaid Services ([CMS](cms.gov)) is a federal agency within the United States Department of Health and Human Services (HHS) that administers the **Medicare program** and works in partnership with state governments to administer Medicaid, the Children's Health Insurance Program (CHIP), and health insurance portability standards.
#  - **Medicare** is a national health insurance program that provides health insurance for Americans aged 65 and over
#
# The **Medicare Part D** program, also called the Medicare prescription drug benefit, is an optional United States federal-government program to help Medicare beneficiaries pay for self-administered prescription drugs through prescription drug insurance premiums.
#
# CMS maintains a lot of [public info](https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Part-D-Prescriber) on prescription drugs that are prescribed by individual physicians and other health care **providers** and paid for under the **Medicare Part D** Prescription Drug Program.
#
# I downloaded the **2017 Provider Summary table** and sampled it down from 1.1 million records (360 MB) to roughly 6000 records (2MB). If you would like to check out the original dataset, you can download it from this site https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/PartD2017
#
# But for this assignment, you need to use the provided downsampled dataset `part_d_drug_prescriptions_sample2.csv`. If you would like, the data dictionary is available [here](https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Downloads/Prescriber_Methods.pdf). The applicable section is Table 2 in the Appendix.

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_rows', 200)

import numpy as np

# %% [markdown]
# ## Question 1
#
# Use Pandas to import **part_d_drug_prescriptions_sample2.csv** into a DataFrame, named `part_d`. How many rows and colums does the dataset have?

# %%
part_d = pd.read_csv('/Users/user/Downloads/part_d_drug_prescriptions_sample2.csv')

# %%
part_d.shape # The dataset has 5815 rows and 84 columns
# Out:
# (5815, 84)

# %% [markdown]
# ## Question 2
# This question has two parts:
# 1. Display the first 6 rows of `part_d`.
# 2. Display the last 6 rows of `part_d`.

# %%
part_d.head(6)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003012022                      CUDZILO                     COREY
# 2  1003020041                       BAXTER                  MARGARET
# 3  1003031212                       KAYALI                      FADI
# 4  1003043175                       BENSON                   REBECCA
# 5  1003054206                       SEILER                    WARREN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     F                 I
# 3               NaN              M.D.                     M                 I
# 4                 L            D.D.S.                     F                 I
# 5                 B                MD                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# 0           900 SETON DR                    NaN          CUMBERLAND  ...
# 1    2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE  ...
# 2      1100 LONG POND RD              SUITE 250           ROCHESTER  ...
# 3     600 N CATTLEMEN RD              SUITE 200            SARASOTA  ...
# 4     6601 LYNDALE AVE S                    NaN           RICHFIELD  ...
# 5         2700 ROGERS DR              SUITE 101            HOMEWOOD  ...
#
#    beneficiary_male_count  beneficiary_race_white_count  \
# 0                    92.0                         220.0
# 1                    35.0                           NaN
# 2                   221.0                         544.0
# 3                   140.0                         249.0
# 4                     NaN                           NaN
# 5                     NaN                           NaN
#
#   beneficiary_race_black_count beneficiary_race_asian_pi_count  \
# 0                         14.0                             0.0
# 1                          NaN                             0.0
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          0.0                             0.0
# 5                          NaN                             NaN
#
#   beneficiary_race_hispanic_count beneficiary_race_nat_ind_count  \
# 0                             0.0                            0.0
# 1                             NaN                            0.0
# 2                            17.0                            0.0
# 3                             NaN                            0.0
# 4                             0.0                            0.0
# 5                             NaN                            NaN
#
#   beneficiary_race_other_count  beneficiary_nondual_count  \
# 0                          0.0                      143.0
# 1                          0.0                       49.0
# 2                         26.0                      515.0
# 3                          NaN                      229.0
# 4                          NaN                       20.0
# 5                          NaN                        NaN
#
#    beneficiary_dual_count  beneficiary_average_risk_score
# 0                    91.0                          2.1685
# 1                    33.0                          2.5022
# 2                    95.0                          1.0164
# 3                    45.0                          2.4311
# 4                     0.0                          1.0910
# 5                     NaN                             NaN
#
# [6 rows x 84 columns]

# %%
part_d.tail(6)
# Out:
#              npi nppes_provider_last_org_name nppes_provider_first_name  \
# 5809  1992936330                       MANLEY               CHRISTOPHER
# 5810  1992949150                         WANG                       AMY
# 5811  1992961429                       PARKER                   MELINDA
# 5812  1992969141                      BURKART                      NORA
# 5813  1992980767                 TANAWUTTIWAT                  TANYANAN
# 5814  1992994446                       PATETE                   MICHAEL
#
#      nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 5809                 J                MD                     M
# 5810                 M                MD                     F
# 5811                 S              PA-C                     F
# 5812                 E              M.D.                     F
# 5813               NaN              M.D.                     F
# 5814                 L          MD, FACS                     M
#
#      nppes_entity_code  nppes_provider_street1 nppes_provider_street2  \
# 5809                 I         333 COTTMAN AVE                    NaN
# 5810                 I  3130 N COUNTY ROAD 25A                    NaN
# 5811                 I          3209 S 23RD ST                STE 340
# 5812                 I     1805 HENNEPIN AVE N                    NaN
# 5813                 I         2500 N STATE ST                    NaN
# 5814                 I          213 PALERMO PL                    NaN
#
#      nppes_provider_city  ...  beneficiary_male_count  \
# 5809        PHILADELPHIA  ...                    25.0
# 5810                TROY  ...                    73.0
# 5811              TACOMA  ...                    59.0
# 5812             GLENCOE  ...                    11.0
# 5813             JACKSON  ...                    84.0
# 5814              VENICE  ...                   472.0
#
#       beneficiary_race_white_count beneficiary_race_black_count  \
# 5809                           NaN                          NaN
# 5810                         168.0                         24.0
# 5811                           NaN                          0.0
# 5812                           NaN                          0.0
# 5813                           NaN                         79.0
# 5814                         951.0                          NaN
#
#      beneficiary_race_asian_pi_count beneficiary_race_hispanic_count  \
# 5809                             NaN                             0.0
# 5810                             NaN                             NaN
# 5811                             0.0                             0.0
# 5812                             0.0                             NaN
# 5813                             NaN                             NaN
# 5814                             NaN                             NaN
#
#      beneficiary_race_nat_ind_count beneficiary_race_other_count  \
# 5809                            0.0                          NaN
# 5810                            0.0                          NaN
# 5811                            0.0                          NaN
# 5812                            0.0                          0.0
# 5813                            NaN                          0.0
# 5814                            NaN                         19.0
#
#       beneficiary_nondual_count  beneficiary_dual_count  \
# 5809                        NaN                     NaN
# 5810                      146.0                    58.0
# 5811                        NaN                     NaN
# 5812                        NaN                     NaN
# 5813                       75.0                    78.0
# 5814                      948.0                    35.0
#
#       beneficiary_average_risk_score
# 5809                          2.5471
# 5810                          2.0090
# 5811                          0.9592
# 5812                          1.3618
# 5813                          2.0090
# 5814                          1.2319
#
# [6 rows x 84 columns]

# %% [markdown]
# ## Question 3
# This question has 4 parts:
# 1. Use the `info()` function to examine the DataFrame from a high level. Take a moment to look at the number of non-null values and the datatypes of each column.
# 2. How many non-null values does the `npi` column have? (Use the output of the `info()` function to answer this question.)
# 3. What is the data type of the `npi` column? (Use the output of the `info()` function to answer this question.)
# 4. The purpose of this question is to understand the data you are looking at. The `npi` stands for National Provider Identifier. Please provide a one or two sentence description of the NPI - you may use a web search (google/wikipedia/etc...) to answer this question.

# %%
part_d.info()
# 2. npi column has 5815 non-null values
# 3. The data type of npi is integer (int64)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5815 entries, 0 to 5814
# Data columns (total 84 columns):
# npi                                 5815 non-null int64
# nppes_provider_last_org_name        5815 non-null object
# nppes_provider_first_name           5815 non-null object
# nppes_provider_mi                   4074 non-null object
# nppes_credentials                   5461 non-null object
# nppes_provider_gender               5815 non-null object
# nppes_entity_code                   5815 non-null object
# nppes_provider_street1              5815 non-null object
# nppes_provider_street2              2107 non-null object
# nppes_provider_city                 5815 non-null object
# nppes_provider_zip5                 5815 non-null float64
# nppes_provider_zip4                 5031 non-null float64
# nppes_provider_state                5815 non-null object
# nppes_provider_country              5815 non-null object
# specialty_description               5815 non-null object
# description_flag                    5815 non-null object
# medicare_prvdr_enroll_status        5815 non-null object
# total_claim_count                   5815 non-null int64
# total_30_day_fill_count             5815 non-null float64
# total_drug_cost                     5815 non-null float64
# total_day_supply                    5815 non-null int64
# bene_count                          5186 non-null float64
# ge65_suppress_flag                  1295 non-null object
# total_claim_count_ge65              4520 non-null float64
# total_30_day_fill_count_ge65        4520 non-null float64
# total_drug_cost_ge65                4520 non-null float64
# total_day_supply_ge65               4520 non-null float64
# bene_count_ge65_suppress_flag       2595 non-null object
# bene_count_ge65                     3220 non-null float64
# brand_suppress_flag                 2324 non-null object
# brand_claim_count                   3491 non-null float64
# brand_drug_cost                     3491 non-null float64
# generic_suppress_flag               1573 non-null object
# generic_claim_count                 4242 non-null float64
# generic_drug_cost                   4242 non-null float64
# other_suppress_flag                 1224 non-null object
# other_claim_count                   4591 non-null float64
# other_drug_cost                     4591 non-null float64
# mapd_suppress_flag                  1096 non-null object
# mapd_claim_count                    4719 non-null float64
# mapd_drug_cost                      4719 non-null float64
# pdp_suppress_flag                   1096 non-null object
# pdp_claim_count                     4719 non-null float64
# pdp_drug_cost                       4719 non-null float64
# lis_suppress_flag                   1191 non-null object
# lis_claim_count                     4624 non-null float64
# lis_drug_cost                       4624 non-null float64
# nonlis_suppress_flag                1191 non-null object
# nonlis_claim_count                  4624 non-null float64
# nonlis_drug_cost                    4624 non-null float64
# opioid_claim_count                  4225 non-null float64
# opioid_drug_cost                    4225 non-null float64
# opioid_day_supply                   4225 non-null float64
# opioid_bene_count                   3954 non-null float64
# opioid_prescriber_rate              4225 non-null float64
# la_opioid_claim_count               5099 non-null float64
# la_opioid_drug_cost                 5099 non-null float64
# la_opioid_day_supply                5099 non-null float64
# la_opioid_bene_count                4703 non-null float64
# la_opioid_prescriber_rate           3340 non-null float64
# antibiotic_claim_count              4112 non-null float64
# antibiotic_drug_cost                4112 non-null float64
# antibiotic_bene_count               3812 non-null float64
# antipsych_ge65_suppress_flag        788 non-null object
# antipsych_claim_count_ge65          5027 non-null float64
# antipsych_drug_cost_ge65            5027 non-null float64
# antipsych_bene_ge65_suppress_flg    1254 non-null object
# antipsych_bene_count_ge65           4561 non-null float64
# average_age_of_beneficiaries        5186 non-null float64
# beneficiary_age_less_65_count       3220 non-null float64
# beneficiary_age_65_74_count         2675 non-null float64
# beneficiary_age_75_84_count         1815 non-null float64
# beneficiary_age_greater_84_count    1935 non-null float64
# beneficiary_female_count            4157 non-null float64
# beneficiary_male_count              4157 non-null float64
# beneficiary_race_white_count        2848 non-null float64
# beneficiary_race_black_count        2004 non-null float64
# beneficiary_race_asian_pi_count     2585 non-null float64
# beneficiary_race_hispanic_count     2006 non-null float64
# beneficiary_race_nat_ind_count      4176 non-null float64
# beneficiary_race_other_count        1784 non-null float64
# beneficiary_nondual_count           3455 non-null float64
# beneficiary_dual_count              3455 non-null float64
# beneficiary_average_risk_score      5186 non-null float64
# dtypes: float64(56), int64(3), object(25)
# memory usage: 3.7+ MB

# %%
# 4. A National Provider Identifier (NPI) is a unique 10-digit identification number issued to health care
# providers in the United States by the Centers for Medicare and Medicaid Services. This is an intelligence free
# identifier, which means that the numbers do not carry information about health care providers, such as the state
# in which they practice or their provider type or specialization.

# %% [markdown]
# ## Question 4
# Take a look at the `nppes_provider_state` column. Compute the number of unique values in this column using at least two different methods.

# %%
part_d['nppes_provider_state']
# Out:
# 0       MD
# 1       TN
# 2       NY
# 3       FL
# 4       MN
# 5       AL
# 6       TX
# 7       MN
# 8       AZ
# 9       TX
# 10      NY
# 11      LA
# 12      NY
# 13      TX
# 14      PA
# 15      NC
# 16      CA
# 17      MO
# 18      NY
# 19      MD
# 20      CA
# 21      NY
# 22      FL
# 23      NY
# 24      IN
# 25      MO
# 26      MA
# 27      OK
# 28      AZ
# 29      VA
# 30      OH
# 31      PA
# 32      TX
# 33      CT
# 34      FL
# 35      PA
# 36      OK
# 37      GA
# 38      NY
# 39      VA
# 40      IL
# 41      IN
# 42      NV
# 43      AZ
# 44      MI
# 45      NC
# 46      NY
# 47      CA
# 48      NJ
# 49      CO
# 50      NV
# 51      LA
# 52      MA
# 53      LA
# 54      MA
# 55      MI
# 56      CO
# 57      SC
# 58      NJ
# 59      OK
# 60      NH
# 61      ME
# 62      CA
# 63      CA
# 64      WA
# 65      CA
# 66      TX
# 67      NY
# 68      GA
# 69      PA
# 70      MS
# 71      ME
# 72      NY
# 73      TX
# 74      MA
# 75      ME
# 76      CA
# 77      RI
# 78      CA
# 79      PA
# 80      KY
# 81      WA
# 82      PA
# 83      TX
# 84      AZ
# 85      CA
# 86      AZ
# 87      IL
# 88      KS
# 89      OR
# 90      GA
# 91      TN
# 92      OR
# 93      OK
# 94      GA
# 95      MD
# 96      CA
# 97      TX
# 98      WI
# 99      NC
#         ..
# 5715    FL
# 5716    CA
# 5717    WV
# 5718    FL
# 5719    IL
# 5720    NY
# 5721    GA
# 5722    MN
# 5723    PA
# 5724    NY
# 5725    CA
# 5726    NM
# 5727    NY
# 5728    NY
# 5729    NY
# 5730    CO
# 5731    VA
# 5732    NY
# 5733    MN
# 5734    CA
# 5735    NC
# 5736    PR
# 5737    CA
# 5738    NY
# 5739    CA
# 5740    AZ
# 5741    MD
# 5742    NM
# 5743    OH
# 5744    MI
# 5745    IL
# 5746    PA
# 5747    TN
# 5748    CA
# 5749    CA
# 5750    NC
# 5751    MI
# 5752    NC
# 5753    IN
# 5754    CA
# 5755    CA
# 5756    NJ
# 5757    PA
# 5758    UT
# 5759    ND
# 5760    MD
# 5761    CA
# 5762    TX
# 5763    FL
# 5764    WI
# 5765    NY
# 5766    PA
# 5767    OH
# 5768    MI
# 5769    TN
# 5770    WA
# 5771    MA
# 5772    IA
# 5773    IA
# 5774    NY
# 5775    NJ
# 5776    TX
# 5777    SC
# 5778    KY
# 5779    NY
# 5780    NY
# 5781    CA
# 5782    NY
# 5783    WA
# 5784    NJ
# 5785    AR
# 5786    SC
# 5787    NM
# 5788    NY
# 5789    LA
# 5790    OH
# 5791    KS
# 5792    AL
# 5793    OH
# 5794    KY
# 5795    NY
# 5796    CA
# 5797    MI
# 5798    WY
# 5799    TX
# 5800    AL
# 5801    GA
# 5802    DC
# 5803    CA
# 5804    KS
# 5805    OK
# 5806    CA
# 5807    IN
# 5808    MN
# 5809    PA
# 5810    OH
# 5811    WA
# 5812    MN
# 5813    MS
# 5814    FL
# Name: nppes_provider_state, Length: 5815, dtype: object

# %%
# Method 1
list1 = list(set(part_d['nppes_provider_state']))
len(list1)
# Out:
# 55

# %%
# Method 2
list2 = np.array(part_d['nppes_provider_state'])
unique_value = np.unique(list2)
len(unique_value)
# Out:
# 55

# %% [markdown]
# ## Question 5
# Let's take a look at the `specialty_description` column. Use the `value_counts()` method to determine the TOP 5 specialties in the dataset as well as their frequencies.

# %%
spe_value = part_d['specialty_description'].value_counts()

# %%
spe_value.head(5)
# Out:
# Nurse Practitioner     785
# Dentist                647
# Internal Medicine      626
# Family Practice        565
# Physician Assistant    446
# Name: specialty_description, dtype: int64

# %% [markdown]
# ## Question 6
# This question has four parts:
# 1. Define a variable `N` equal to the number of rows in the DataFrame, using the DataFrame `len` or `shape` methods.
# 2. Append the `cumsum()` function to the output of the `value_counts()` function on the `specialty_description` field  and divide the output by `N` to obtain the cumulative ratio to the total count.
# 3. Create a boolean variable (eg a mask) which resolves to `True` if the cumulative sum is less than 75%, else `False`.
# 4. Use this boolean mask to filter the output of `value_counts()` to identify the columns that contribute to the first 75% of all specialities.

# %%
N = len(part_d)
cumsum = spe_value.cumsum()
ratio = cumsum/N
ratio.head()
# Out:
# Nurse Practitioner     0.134996
# Dentist                0.246260
# Internal Medicine      0.353912
# Family Practice        0.451075
# Physician Assistant    0.527773
# Name: specialty_description, dtype: float64

# %%
mask = ratio < 0.75

# %%
spe_value[mask]
# Out:
# Nurse Practitioner                                                785
# Dentist                                                           647
# Internal Medicine                                                 626
# Family Practice                                                   565
# Physician Assistant                                               446
# Emergency Medicine                                                250
# Student in an Organized Health Care Education/Training Program    250
# Obstetrics & Gynecology                                           203
# Optometry                                                         168
# Psychiatry                                                        152
# General Surgery                                                   121
# Ophthalmology                                                     115
# Name: specialty_description, dtype: int64

# %% [markdown]
# ## Question 7:
# Take a look at these two columns: `total_claim_count` and `opioid_claim_count`. Define a new column that stores the ratio of the two, eg:
# ```python
# part_d['opioid_claim_rate'] = part_d['opioid_claim_count']/part_d['total_claim_count']
# ```
# Let us define **high opioid providers** as those who have an `opioid_claim_rate` that is greater than or equal to 50%. This question has three parts:
# 1. Run the describe method on the `opioid_claim_rate` column and note the statistics.
# 2. Use TWO different methods to calculate how many **high opioid providers** there are in the dataset. (Hint: you can use the sum of a boolean variable for one method and the size of a filtered dataset for the other method).
# 3. Use TWO different methods to identify the top 3 states that have the highest number of **high opioid providers**. (Hint: you can use value_counts for one method and groupby for the other method).

# %%
part_d['opioid_claim_rate'] = part_d['opioid_claim_count']/part_d['total_claim_count']
part_d['opioid_claim_rate'].describe()
# Out:
# count    4225.000000
# mean        0.097227
# std         0.164038
# min         0.000000
# 25%         0.000000
# 50%         0.022523
# 75%         0.113238
# max         1.000000
# Name: opioid_claim_rate, dtype: float64

# %%
# 2. Method 1
high_opioid = part_d['opioid_claim_rate'] >= 0.5
sum(high_opioid == True)
# Out:
# 209

# %%
# 2. Method 2
len(part_d[part_d['opioid_claim_rate'] >= 0.5])
# Out:
# 209

# %%
# 3. Method 1
part_d['high_opioid'] = high_opioid
state2 = part_d.loc[part_d['high_opioid'] == True,['nppes_provider_state']]
n = state2['nppes_provider_state'].value_counts()
print(n.head(4))
# MI and NY has the same numbers. The top 3 states that have the highest number of high opioid providers are CA, FL,
# NY and MI.
# Out:
# CA    19
# FL    15
# MI    12
# NY    12
# Name: nppes_provider_state, dtype: int64

# %%
# 3. Method 2
state = part_d.groupby(by=['nppes_provider_state'])[['high_opioid']].sum()
state.nlargest(4, 'high_opioid')
# Out:
#                       high_opioid
# nppes_provider_state
# CA                           19.0
# FL                           15.0
# MI                           12.0
# NY                           12.0

# %% [markdown]
# ## Question 8:
# Using the `opioid_claim_rate` column computed in the previous question:
#
# 1. Create a new DataFrame `g` that aggregates the `nppes_provider_gender` column using the `groupby` method and the `size` function to output the gender breakdown in the dataset. You can use this code to answer this question:
# ```python
# g = part_d.groupby('nppes_provider_gender').size().reset_index()
# ```
# 2. Use the `rename` method to rename the columns of DataFrame `g` to *gender* and *count*.
# 3. Now compute the aggregation of the dataset by gender but filtered to the **high opioid providers**. Name the DataFrame `g2`. Rename the columns to *gender* and *high_opioid_count*.
# 4. Join the DataFrames g and g2 using the gender column as the key. The final result should look like this:
# ```
# gender	count	high_opioid_count
# 	F	2458	62
# 	M	3357	147
# ```
# 5. Compute the ratio of `high_opioid_count` to `count` for each row and note the difference

# %%
g = part_d.groupby('nppes_provider_gender').size().reset_index()
g = g.rename(columns = {'nppes_provider_gender':'gender', 0:'count'})
g
# Out:
#   gender  count
# 0      F   2458
# 1      M   3357

# %%
g2 = part_d.groupby('nppes_provider_gender')[['high_opioid']].sum()
g2 = g2.reset_index()
g2 = g2.rename(columns = {'nppes_provider_gender':'gender','high_opioid':'high_opioid_count'})
g2
# Out:
#   gender  high_opioid_count
# 0      F               62.0
# 1      M              147.0

# %%
join = pd.merge(g,g2)
join
# Out:
#   gender  count  high_opioid_count
# 0      F   2458               62.0
# 1      M   3357              147.0

# %%
join['ratio'] = join['high_opioid_count']/join['count']
join
# Out:
#   gender  count  high_opioid_count     ratio
# 0      F   2458               62.0  0.025224
# 1      M   3357              147.0  0.043789

# %%
difference = join['ratio'].diff()
difference
# The difference between two ratios is 0.018565
# Out:
# 0         NaN
# 1    0.018565
# Name: ratio, dtype: float64

# %% [markdown]
# ## Question 9:
# The Office of Inspector General ([OIG](https://oig.hhs.gov/)) has the authority to **exclude** individuals and entities from Federally funded health care programs. To be excluded is quite serious, as you can see from their website:
#
# >The OIG maintains a list of all currently excluded individuals and entities called the List of Excluded Individuals/Entities (LEIE). Anyone who hires an individual or entity on the LEIE may be subject to civil monetary penalties (CMP). To avoid CMP liability, health care entities should routinely check the list to ensure that new hires and current employees are not on it.
#
# This list is publicaly available, [here](https://oig.hhs.gov/exclusions/exclusions_list.asp). I have downloaded this file in its entirety (in December 2020) and have stripped it down to the columns we need.
#
# Load the provided file into a DataFrame, named `exclusions`:
#
# ```python
# exclusions = pd.read_csv('physicians_exclusions_sample3.csv')
# ```
# This question has a number of parts:
#
# 1. Print the number of rows and columns in the exclusions dataset.
# 2. Display the first 6 rows the DataFrame.
# 3. Display 3 random rows of the DataFrame using the `sample` method.
# 4. Use the `nunique` method to determine the number of unique NPIs. Compare this to the size of the dataset - what do you observe?
# 5. Are there any NULL `NPI` values?
# 6. What is the most frequent `NPI` value?
# 7. Apply the `unique` method to the NPI column and convert the outcome to a list of NPIs (hint use the `tolist` method). Store the output in a variable called `npis`. What is the length of `npis`?
# 8. Apply the `isin` method to `part_d` to tag the rows whose NPI is in the list of excluded NPIs. You can use the following code. How many records are there in `excluded1`?
# ```python
# excluded1 = part_d[part_d['npi'].isin(npis)]
# ```

# %%
exclusions = pd.read_csv('/Users/user/Downloads/physicians_exclusions_sample3.csv')
# 1. The dataset has 69858 rows and 4 columns
exclusions.shape
# Out:
# (69858, 4)

# %%
# 2. First 6 rows
exclusions.head(6)
# Out:
#    LASTNAME    FIRSTNAME STATE  NPI
# 0   AALDERS        NANCY    IL    0
# 1  AALTONEN     NICKOLAS    WA    0
# 2     AAMIR     MUHAMMAD    MI    0
# 3     AARON        ALINA    AZ    0
# 4     AARON  CHRISTOPHER    PA    0
# 5     AARON      DEBORAH    TX    0

# %%
# 3. 3 random rows
exclusions.sample(3)
# Out:
#       LASTNAME FIRSTNAME STATE  NPI
# 18244     EMBS    MONICA    NY    0
# 8777      BURT    NICOLE    RI    0
# 14341    DALEY   REBECCA    ME    0

# %%
# 4. nunique
exclusions['NPI'].nunique()
# Compare to the total attributes, the number of unique NPI is quite small, only about 7.4% of them has a unique NPI.
# Out:
# 5200

# %%
# 5. There is no null value in NPI column
exclusions['NPI'].isnull().sum()
# Out:
# 0

# %%
# 6. The most frequent value in NPI column is 0
exclusions['NPI'].value_counts().head(1)
# Out:
# 0    64621
# Name: NPI, dtype: int64

# %%
# 7. The length of npis is 5200
npis = np.unique(exclusions['NPI']).tolist()
print(len(npis))
# Out:
# 5200

# %%
# 8. There are 2 records in excluded1
excluded1 = part_d[part_d['npi'].isin(npis)]
excluded1.shape
# Out:
# (2, 86)

# %% [markdown]
# ## Question 10
# In question 9 we searched for records in the part_d DataFrame whose NPI was in the exclusions dataset. Matching across the NPI yielded only 2 excluded providers. This seems suspicious. The problem is probably due to the fact that so many of the NPIs in the excluded dataset are marked as `0`. Perhaps we can do better by matching across first and last names. Let's do that in these steps.
# 1. As a sanity check, let's first do a merge between the two datasets on NPI. Your results should confirm the result obtained in question 9. For convenience, define this list of columns:
# ```python
# cols = [
#     'npi',
#     'nppes_provider_first_name',
#     'nppes_provider_last_org_name',
#     'nppes_provider_state',
#     'NPI',
#     'FIRSTNAME',
#     'LASTNAME',
#     'STATE',
#     'opioid_claim_rate'
# ]
# ```
# Perform the merge and display the output for the columns in `cols`. You can use the following code to answer this question:
# ```python
# excluded2 = pd.merge(left = part_d, right = exclusions, how = 'inner',
#          left_on = ['npi'],
#          right_on = ['NPI']
#         )
# excluded2[cols]
# ```
# Your results should match the results from Question 9.
#
#
# 2. Since we are going to match across names, let's first convert the applicable columns to upper case and strip out any leading or trailing spaces. You can use the following code to answer this question but you'll need to apply it to the remaining first and last name columns, eg 'nppes_provider_first_name', 'nppes_provider_last_org_name', 'FIRSTNAME' and 'LASTNAME'
# ```python
# part_d['nppes_provider_first_name'] = part_d['nppes_provider_first_name'].str.upper().str.strip()
# ```
#
# 3. Run another inner join across both datasets using first and last names. My result had 461 rows. Please take a look at the dataset filtering on the columns in `cols` as done above. What do you notice?
#
#
# 4. In order to conduct a better quality match, include the state in your join keys. You should now be matching on first name, last name and state. My result had 22 records. I feel more confident in this match since the names and state lines up. You'll notice that some of the providers have 0 `opioid_claim_rate`. This is not that surprising as there are many different kinds of behaviors that a provider can engage in in order to get on the exclusisons list.

# %%
cols = [
    'npi', 
    'nppes_provider_first_name', 
    'nppes_provider_last_org_name', 
    'nppes_provider_state', 
    'NPI',
    'FIRSTNAME',
    'LASTNAME',
    'STATE',
    'opioid_claim_rate'
]

excluded2 = pd.merge(left = part_d, right = exclusions, how = 'inner', 
      left_on = ['npi'],
      right_on = ['NPI']
     )
excluded2[cols]
# Out:
#           npi nppes_provider_first_name nppes_provider_last_org_name  \
# 0  1659506111                   DESMOND                      FRANCIS
# 1  1770505612                  HARRISON                         YANG
#
#   nppes_provider_state         NPI FIRSTNAME LASTNAME STATE  opioid_claim_rate
# 0                   NY  1659506111   DESMOND  FRANCIS    NY           0.089926
# 1                   TN  1770505612  HARRISON     YANG    TN           0.119433

# %%
part_d['nppes_provider_first_name'] = part_d['nppes_provider_first_name'].str.upper().str.strip()
part_d['nppes_provider_last_org_name'] = part_d['nppes_provider_last_org_name'].str.upper().str.strip()
exclusions['FIRSTNAME'] = exclusions['FIRSTNAME'].str.upper().str.strip()
exclusions['LASTNAME'] = exclusions['LASTNAME'].str.upper().str.strip()

# %%
# 3.
excluded3 = pd.merge(left = part_d, right = exclusions, how = 'inner', 
      left_on = ['nppes_provider_first_name','nppes_provider_last_org_name'],
      right_on = ['FIRSTNAME','LASTNAME']
     )
excluded3[cols]
# There are 435 records in excluded3. The records which have the same name have different states.
# Out:
#             npi nppes_provider_first_name nppes_provider_last_org_name  \
# 0    1003153628                   RICHARD                      COLEMAN
# 1    1003290974                   MARILYN                        JONES
# 2    1003811837                      MARK                     ROBINSON
# 3    1346286507                      MARK                     ROBINSON
# 4    1003868787                   DOUGLAS                       NELSON
# 5    1013070861                   CHARLES                       HARRIS
# 6    1013070861                   CHARLES                       HARRIS
# 7    1013123579                      JOHN                      O'BRIEN
# 8    1013912013                   KATHRYN                         LEVY
# 9    1013926930                  JENNIFER                      GRIFFIN
# 10   1013950492                   CHARLES                      JOHNSON
# 11   1013950492                   CHARLES                      JOHNSON
# 12   1013950492                   CHARLES                      JOHNSON
# 13   1013950492                   CHARLES                      JOHNSON
# 14   1013955855                        VU                       NGUYEN
# 15   1023010535                   MICHAEL                    ROSENBERG
# 16   1023032414                     SCOTT                      MCGUIRE
# 17   1023141660                      LUIS                        GARZA
# 18   1023272309                    KHALED                       HASSAN
# 19   1023320173                      NGOC                         TRAN
# 20   1023472123                       VAN                       NGUYEN
# 21   1033193727                    THOMAS                        DAVIS
# 22   1033293634                     JAMES                         HAHN
# 23   1033313374                    THOMAS                        JONES
# 24   1043236177                      MARK                     ANDERSON
# 25   1053315028                   WILLIAM                      JOHNSON
# 26   1053315028                   WILLIAM                      JOHNSON
# 27   1053315028                   WILLIAM                      JOHNSON
# 28   1053315028                   WILLIAM                      JOHNSON
# 29   1053315028                   WILLIAM                      JOHNSON
# 30   1053315028                   WILLIAM                      JOHNSON
# 31   1053349506                      JOSE                       TORRES
# 32   1053557678                   REBECCA                        BAKER
# 33   1053590851                   DEBORAH                          ROE
# 34   1053727784                   LINDSEY                       BROOKS
# 35   1063406411                     DAVID                        HENRY
# 36   1063406411                     DAVID                        HENRY
# 37   1063406411                     DAVID                        HENRY
# 38   1063654614                    THOMAS                      GILMORE
# 39   1063724003                 NATHANIEL                      STEVENS
# 40   1073735445                   KATRINA                      JACKSON
# 41   1073735445                   KATRINA                      JACKSON
# 42   1083140917                      JUAN                     GONZALEZ
# 43   1083680136                  PATRICIA                     SULLIVAN
# 44   1083685002                   MICHAEL                        MOORE
# 45   1083685002                   MICHAEL                        MOORE
# 46   1083685002                   MICHAEL                        MOORE
# 47   1093730376                     DAVID                      CORNELL
# 48   1093800237                  JENNIFER                       THOMAS
# 49   1093800237                  JENNIFER                       THOMAS
# 50   1093800237                  JENNIFER                       THOMAS
# 51   1104116235                      JOHN                        DAVIS
# 52   1104116235                      JOHN                        DAVIS
# 53   1104800622                     CRAIG                        WHITE
# 54   1104938380                    ROBERT                     PETERSON
# 55   1104938380                    ROBERT                     PETERSON
# 56   1114030830                      JOHN                      SANDERS
# 57   1114030830                      JOHN                      SANDERS
# 58   1114030830                      JOHN                      SANDERS
# 59   1114112331                    MAGGIE                     WILLIAMS
# 60   1114305927                   CYNTHIA                        WOODS
# 61   1114331634                    DIANNE                        DAVIS
# 62   1124188081                  MOHAMMED                        SAEED
# 63   1134113996                     DAVID                        BROWN
# 64   1134113996                     DAVID                        BROWN
# 65   1134113996                     DAVID                        BROWN
# 66   1134113996                     DAVID                        BROWN
# 67   1134113996                     DAVID                        BROWN
# 68   1134157639                      LISA                         RYAN
# 69   1134214158                      JOHN                        SMITH
# 70   1134214158                      JOHN                        SMITH
# 71   1144278052                    ROBERT                       TAYLOR
# 72   1144278052                    ROBERT                       TAYLOR
# 73   1144382672                      MARY                        SMITH
# 74   1144382672                      MARY                        SMITH
# 75   1144382672                      MARY                        SMITH
# 76   1144382672                      MARY                        SMITH
# 77   1144382672                      MARY                        SMITH
# 78   1144382672                      MARY                        SMITH
# 79   1144382672                      MARY                        SMITH
# 80   1144649062                     PAULA                        SMITH
# 81   1154310373                     JERRY                       WALKER
# 82   1154373520                   WILLIAM                     ANDERSON
# 83   1154373520                   WILLIAM                     ANDERSON
# 84   1154614469                   JESSICA                     CRADDOCK
# 85   1164447181                   MICHAEL                        GREEN
# 86   1164447181                   MICHAEL                        GREEN
# 87   1396131124                   MICHAEL                        GREEN
# 88   1396131124                   MICHAEL                        GREEN
# 89   1164583944                     JAMES                        BROWN
# 90   1164583944                     JAMES                        BROWN
# 91   1164583944                     JAMES                        BROWN
# 92   1164583944                     JAMES                        BROWN
# 93   1164583944                     JAMES                        BROWN
# 94   1164583944                     JAMES                        BROWN
# 95   1164583944                     JAMES                        BROWN
# 96   1164583944                     JAMES                        BROWN
# 97   1164583944                     JAMES                        BROWN
# 98   1164583944                     JAMES                        BROWN
# 99   1164601209                    JOSEPH                     DAVIDSON
# ..          ...                       ...                          ...
# 335  1740228055                      JOHN                       TAYLOR
# 336  1740234079                   ANTHONY                        DAVIS
# 337  1740234079                   ANTHONY                        DAVIS
# 338  1740249408                    THOMAS                          LEE
# 339  1740471770                    AMANDA                       MILLER
# 340  1750362836                   MICHAEL                        GLASS
# 341  1750662367                   RICHARD                        JONES
# 342  1750688362                   DEBORAH                       THOMAS
# 343  1750688362                   DEBORAH                       THOMAS
# 344  1750688362                   DEBORAH                       THOMAS
# 345  1750725990                JACQUELINE                        LEWIS
# 346  1770505612                  HARRISON                         YANG
# 347  1770545139                     KELLY                    SCHROEDER
# 348  1770713620                 ELIZABETH                       WILSON
# 349  1770713620                 ELIZABETH                       WILSON
# 350  1770713620                 ELIZABETH                       WILSON
# 351  1780780098                      LISA                       FOSTER
# 352  1780823724                      ADAM                          LEE
# 353  1780904706                      SEAN                         RYAN
# 354  1790876373                   WILLIAM                        MEYER
# 355  1790883528                  KATHLEEN                       MILLER
# 356  1801260096                    GERALD                       NELSON
# 357  1801897251                     DAVID                        MAJOR
# 358  1811041767                     JAMES                       MADDOX
# 359  1821051483                    ANDREW                         ROSS
# 360  1821136136                    ROBERT                         WOLF
# 361  1821136136                    ROBERT                         WOLF
# 362  1821222324                    DANIEL                        WHITE
# 363  1821299397                    ANGELA                      SANCHEZ
# 364  1821541152                      MARY                        CLARK
# 365  1831586858                    NICOLE                         COOK
# 366  1841206554                    ANGELA                          KIM
# 367  1841257144                   RICHARD                          LEE
# 368  1841261963                   RICHARD                        COHEN
# 369  1841293511                   WILLIAM                        CLARK
# 370  1841310646                     JAMES                        BERRY
# 371  1841731924                      MARK                        DAVIS
# 372  1841731924                      MARK                        DAVIS
# 373  1841731924                      MARK                        DAVIS
# 374  1851330104                   WILLIAM                    ROBERTSON
# 375  1851330104                   WILLIAM                    ROBERTSON
# 376  1861409690                   HEATHER                        MOORE
# 377  1861477077                    ROBERT                        MOYER
# 378  1861566648                  PATRICIA                          LEE
# 379  1861603946               CHRISTOPHER                       WAGNER
# 380  1861650343                     JAMES                      COLLINS
# 381  1871533315                 ELIZABETH                     CAMPBELL
# 382  1871586685                     DAVID                         WOOD
# 383  1871586685                     DAVID                         WOOD
# 384  1871709840                     JAMES                        GREEN
# 385  1871709840                     JAMES                        GREEN
# 386  1871709840                     JAMES                        GREEN
# 387  1871792127                     DAVID                        GREEN
# 388  1871955906                    CARMEN                        LOPEZ
# 389  1871955906                    CARMEN                        LOPEZ
# 390  1881617975                   DEBORAH                     WILLIAMS
# 391  1881617975                   DEBORAH                     WILLIAMS
# 392  1881617975                   DEBORAH                     WILLIAMS
# 393  1881617975                   DEBORAH                     WILLIAMS
# 394  1881791986                   BRADLEY                      COLLINS
# 395  1902003973                      JOHN                          KIM
# 396  1902095631                    DANIEL                        YOUNG
# 397  1902327612                     LAURA                       SANTOS
# 398  1902927213                  JENNIFER                     HASTINGS
# 399  1922017235                    THOMAS                      VAUGHAN
# 400  1922035120                    THOMAS                        WILEY
# 401  1922166495                    RONALD                       HARRIS
# 402  1922189869                    THOMAS                      JOHNSON
# 403  1922189869                    THOMAS                      JOHNSON
# 404  1932128840                   CYNTHIA                        BROWN
# 405  1932128840                   CYNTHIA                        BROWN
# 406  1932244894                    RAFAEL                         DIAZ
# 407  1942309596                 MARGARITA                    RODRIGUEZ
# 408  1942428354                   MICHAEL                        SMITH
# 409  1942428354                   MICHAEL                        SMITH
# 410  1942428354                   MICHAEL                        SMITH
# 411  1942428354                   MICHAEL                        SMITH
# 412  1942428354                   MICHAEL                        SMITH
# 413  1942428354                   MICHAEL                        SMITH
# 414  1942428354                   MICHAEL                        SMITH
# 415  1942592324                  JENNIFER                        SMITH
# 416  1942592324                  JENNIFER                        SMITH
# 417  1942592324                  JENNIFER                        SMITH
# 418  1942592324                  JENNIFER                        SMITH
# 419  1942726054                    ROBERT                      GARRETT
# 420  1942726054                    ROBERT                      GARRETT
# 421  1952342982                     JAMES                        PAYNE
# 422  1962455741                      HIEU                       NGUYEN
# 423  1962512996                  KATHLEEN                       HUGHES
# 424  1962692269                    RONALD                        OWENS
# 425  1972800894                   JEFFREY                       SCHERR
# 426  1972913556                     BRIAN                        STONE
# 427  1982082921                     DAVID                         GRAY
# 428  1982643318                      JUAN                      JIMENEZ
# 429  1982648333                   TIMOTHY                       MILLER
# 430  1982648333                   TIMOTHY                       MILLER
# 431  1982668497                    ANDREW                     JIMERSON
# 432  1992142632                   JESSICA                     MARSHALL
# 433  1992786305                      JOHN                          FOX
# 434  1992905616                    SHARON                          LEE
#
#     nppes_provider_state         NPI    FIRSTNAME   LASTNAME STATE  \
# 0                     TX           0      RICHARD    COLEMAN    CA
# 1                     IN           0      MARILYN      JONES    AR
# 2                     OH  1427112325         MARK   ROBINSON    NH
# 3                     CA  1427112325         MARK   ROBINSON    NH
# 4                     IL           0      DOUGLAS     NELSON    IA
# 5                     TX           0      CHARLES     HARRIS    MS
# 6                     TX           0      CHARLES     HARRIS    TX
# 7                     NY           0         JOHN    O'BRIEN    WA
# 8                     TX           0      KATHRYN       LEVY    CO
# 9                     NY           0     JENNIFER    GRIFFIN    FL
# 10                    VA           0      CHARLES    JOHNSON    CA
# 11                    VA           0      CHARLES    JOHNSON    TX
# 12                    VA  1780651984      CHARLES    JOHNSON    MO
# 13                    VA  1649381997      CHARLES    JOHNSON    MA
# 14                    NY           0           VU     NGUYEN    CA
# 15                    NJ           0      MICHAEL  ROSENBERG    CA
# 16                    MO           0        SCOTT    MCGUIRE    UT
# 17                    NY           0         LUIS      GARZA    TX
# 18                    CA  1841303310       KHALED     HASSAN    MO
# 19                    LA           0         NGOC       TRAN    CA
# 20                    OH           0          VAN     NGUYEN    MN
# 21                    MN           0       THOMAS      DAVIS    IN
# 22                    CA           0        JAMES       HAHN    OK
# 23                    VA           0       THOMAS      JONES    GA
# 24                    NC  1679640866         MARK   ANDERSON    PA
# 25                    MS           0      WILLIAM    JOHNSON    NC
# 26                    MS  1255381307      WILLIAM    JOHNSON    IL
# 27                    MS           0      WILLIAM    JOHNSON    CA
# 28                    MS           0      WILLIAM    JOHNSON    LA
# 29                    MS           0      WILLIAM    JOHNSON    TN
# 30                    MS           0      WILLIAM    JOHNSON    GA
# 31                    FL           0         JOSE     TORRES    FL
# 32                    IL           0      REBECCA      BAKER    FL
# 33                    WI           0      DEBORAH        ROE    IL
# 34                    VA           0      LINDSEY     BROOKS    AL
# 35                    PA           0        DAVID      HENRY    TX
# 36                    PA  1801915566        DAVID      HENRY    OK
# 37                    PA           0        DAVID      HENRY    CA
# 38                    CT           0       THOMAS    GILMORE    GA
# 39                    WV           0    NATHANIEL    STEVENS    AZ
# 40                    TX           0      KATRINA    JACKSON    CA
# 41                    TX           0      KATRINA    JACKSON    AL
# 42                    TX           0         JUAN   GONZALEZ    FL
# 43                    PA           0     PATRICIA   SULLIVAN    FL
# 44                    NC           0      MICHAEL      MOORE    OK
# 45                    NC           0      MICHAEL      MOORE    KS
# 46                    NC  1023251873      MICHAEL      MOORE    CO
# 47                    IL           0        DAVID    CORNELL    NJ
# 48                    WY           0     JENNIFER     THOMAS    FL
# 49                    WY           0     JENNIFER     THOMAS    AL
# 50                    WY           0     JENNIFER     THOMAS    MS
# 51                    VA           0         JOHN      DAVIS    CA
# 52                    VA           0         JOHN      DAVIS    IL
# 53                    NC           0        CRAIG      WHITE    CA
# 54                    OR           0       ROBERT   PETERSON    NV
# 55                    OR           0       ROBERT   PETERSON    CA
# 56                    TX           0         JOHN    SANDERS    CA
# 57                    TX           0         JOHN    SANDERS    MI
# 58                    TX           0         JOHN    SANDERS    VA
# 59                    NC           0       MAGGIE   WILLIAMS    OK
# 60                    TX           0      CYNTHIA      WOODS    WY
# 61                    OK           0       DIANNE      DAVIS    MS
# 62                    IL           0     MOHAMMED      SAEED    NJ
# 63                    WI           0        DAVID      BROWN    AR
# 64                    WI           0        DAVID      BROWN    WA
# 65                    WI           0        DAVID      BROWN    MN
# 66                    WI           0        DAVID      BROWN    TX
# 67                    WI           0        DAVID      BROWN    AZ
# 68                    CA           0         LISA       RYAN    NJ
# 69                    KY           0         JOHN      SMITH    PA
# 70                    KY  1811966120         JOHN      SMITH    CA
# 71                    CA           0       ROBERT     TAYLOR    CA
# 72                    CA           0       ROBERT     TAYLOR    CT
# 73                    MS           0         MARY      SMITH    TX
# 74                    MS           0         MARY      SMITH    AR
# 75                    MS           0         MARY      SMITH    CA
# 76                    MS           0         MARY      SMITH    NE
# 77                    MS           0         MARY      SMITH    SC
# 78                    MS           0         MARY      SMITH    IL
# 79                    MS           0         MARY      SMITH    MS
# 80                    TN           0        PAULA      SMITH    NC
# 81                    ID           0        JERRY     WALKER    OK
# 82                    CO           0      WILLIAM   ANDERSON    TX
# 83                    CO           0      WILLIAM   ANDERSON    ME
# 84                    WA           0      JESSICA   CRADDOCK    LA
# 85                    IL           0      MICHAEL      GREEN    FL
# 86                    IL           0      MICHAEL      GREEN    MS
# 87                    VA           0      MICHAEL      GREEN    FL
# 88                    VA           0      MICHAEL      GREEN    MS
# 89                    GA           0        JAMES      BROWN    MO
# 90                    GA           0        JAMES      BROWN    TX
# 91                    GA           0        JAMES      BROWN    AZ
# 92                    GA           0        JAMES      BROWN    NC
# 93                    GA           0        JAMES      BROWN    NJ
# 94                    GA           0        JAMES      BROWN    NY
# 95                    GA           0        JAMES      BROWN    CT
# 96                    GA           0        JAMES      BROWN    FL
# 97                    GA           0        JAMES      BROWN    AL
# 98                    GA           0        JAMES      BROWN    TN
# 99                    NY           0       JOSEPH   DAVIDSON    PA
# ..                   ...         ...          ...        ...   ...
# 335                   UT           0         JOHN     TAYLOR    NC
# 336                   FL           0      ANTHONY      DAVIS    TX
# 337                   FL           0      ANTHONY      DAVIS    GA
# 338                   MD           0       THOMAS        LEE    CA
# 339                   WI           0       AMANDA     MILLER    VA
# 340                   OK           0      MICHAEL      GLASS    NY
# 341                   WV           0      RICHARD      JONES    AZ
# 342                   TN           0      DEBORAH     THOMAS    IA
# 343                   TN  1518952951      DEBORAH     THOMAS    TX
# 344                   TN           0      DEBORAH     THOMAS    MS
# 345                   TX           0   JACQUELINE      LEWIS    LA
# 346                   TN  1770505612     HARRISON       YANG    TN
# 347                   MI           0        KELLY  SCHROEDER    FL
# 348                   NM           0    ELIZABETH     WILSON    WI
# 349                   NM           0    ELIZABETH     WILSON    CT
# 350                   NM           0    ELIZABETH     WILSON    NV
# 351                   CO           0         LISA     FOSTER    VT
# 352                   IL           0         ADAM        LEE    MA
# 353                   TX  1982923728         SEAN       RYAN    VT
# 354                   AZ           0      WILLIAM      MEYER    IA
# 355                   IN           0     KATHLEEN     MILLER    OH
# 356                   KS           0       GERALD     NELSON    CA
# 357                   PA           0        DAVID      MAJOR    CA
# 358                   KY           0        JAMES     MADDOX    AL
# 359                   NC           0       ANDREW       ROSS    CA
# 360                   AZ  1396799201       ROBERT       WOLF    HI
# 361                   AZ           0       ROBERT       WOLF    NY
# 362                   MI           0       DANIEL      WHITE    FL
# 363                   NM           0       ANGELA    SANCHEZ    TX
# 364                   GA           0         MARY      CLARK    PA
# 365                   OH           0       NICOLE       COOK    VA
# 366                   CA           0       ANGELA        KIM    FL
# 367                   MA           0      RICHARD        LEE    CA
# 368                   NY           0      RICHARD      COHEN    FL
# 369                   WA           0      WILLIAM      CLARK    MO
# 370                   MA           0        JAMES      BERRY    TX
# 371                   CA           0         MARK      DAVIS    NJ
# 372                   CA  1336145309         MARK      DAVIS    OH
# 373                   CA           0         MARK      DAVIS    MD
# 374                   AZ           0      WILLIAM  ROBERTSON    WA
# 375                   AZ           0      WILLIAM  ROBERTSON    MI
# 376                   WA           0      HEATHER      MOORE    NY
# 377                   DE           0       ROBERT      MOYER    KY
# 378                   CA           0     PATRICIA        LEE    TN
# 379                   MD           0  CHRISTOPHER     WAGNER    CA
# 380                   GA           0        JAMES    COLLINS    TN
# 381                   NC           0    ELIZABETH   CAMPBELL    CA
# 382                   AZ           0        DAVID       WOOD    CA
# 383                   AZ           0        DAVID       WOOD    WA
# 384                   GA           0        JAMES      GREEN    KY
# 385                   GA           0        JAMES      GREEN    TN
# 386                   GA           0        JAMES      GREEN    AZ
# 387                   NY           0        DAVID      GREEN    IA
# 388                   FL           0       CARMEN      LOPEZ    CA
# 389                   FL           0       CARMEN      LOPEZ    FL
# 390                   IL           0      DEBORAH   WILLIAMS    AL
# 391                   IL           0      DEBORAH   WILLIAMS    OK
# 392                   IL           0      DEBORAH   WILLIAMS    MS
# 393                   IL           0      DEBORAH   WILLIAMS    NY
# 394                   CA  1700963055      BRADLEY    COLLINS    OH
# 395                   GA           0         JOHN        KIM    CA
# 396                   UT           0       DANIEL      YOUNG    TX
# 397                   MA  1023077955        LAURA     SANTOS    GA
# 398                   TN  1629125034     JENNIFER   HASTINGS    NY
# 399                   WA           0       THOMAS    VAUGHAN    MS
# 400                   MS           0       THOMAS      WILEY    TX
# 401                   GA           0       RONALD     HARRIS    FL
# 402                   MI           0       THOMAS    JOHNSON    FL
# 403                   MI           0       THOMAS    JOHNSON    OH
# 404                   GA           0      CYNTHIA      BROWN    LA
# 405                   GA           0      CYNTHIA      BROWN    WA
# 406                   PR           0       RAFAEL       DIAZ    CA
# 407                   FL           0    MARGARITA  RODRIGUEZ    FL
# 408                   AK           0      MICHAEL      SMITH    CO
# 409                   AK           0      MICHAEL      SMITH    PA
# 410                   AK  1164482709      MICHAEL      SMITH    CA
# 411                   AK           0      MICHAEL      SMITH    NJ
# 412                   AK  1104898634      MICHAEL      SMITH    NC
# 413                   AK  1932172012      MICHAEL      SMITH    NY
# 414                   AK           0      MICHAEL      SMITH    NC
# 415                   NC           0     JENNIFER      SMITH    WI
# 416                   NC           0     JENNIFER      SMITH    PA
# 417                   NC           0     JENNIFER      SMITH    TN
# 418                   NC           0     JENNIFER      SMITH    NC
# 419                   GA           0       ROBERT    GARRETT    NY
# 420                   GA  1801179726       ROBERT    GARRETT    MO
# 421                   AL           0        JAMES      PAYNE    IN
# 422                   GA  1275513590         HIEU     NGUYEN    CA
# 423                   WA           0     KATHLEEN     HUGHES    NV
# 424                   CO           0       RONALD      OWENS    NC
# 425                   NY           0      JEFFREY     SCHERR    CA
# 426                   PA           0        BRIAN      STONE    AR
# 427                   PA           0        DAVID       GRAY    CA
# 428                   CA           0         JUAN    JIMENEZ    FL
# 429                   WV           0      TIMOTHY     MILLER    LA
# 430                   WV           0      TIMOTHY     MILLER    UT
# 431                   GA  1427056076       ANDREW   JIMERSON    OH
# 432                   OH           0      JESSICA   MARSHALL    FL
# 433                   KS           0         JOHN        FOX    AL
# 434                   CA           0       SHARON        LEE    TX
#
#      opioid_claim_rate
# 0             0.047162
# 1             0.017435
# 2             0.000000
# 3             0.000000
# 4             0.196429
# 5             0.000000
# 6             0.000000
# 7             0.029821
# 8             0.000000
# 9             0.000000
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15            0.000000
# 16                 NaN
# 17            0.000000
# 18            0.074380
# 19            0.297297
# 20            0.439024
# 21            0.000000
# 22            0.002403
# 23            0.000000
# 24            0.017658
# 25            0.070455
# 26            0.070455
# 27            0.070455
# 28            0.070455
# 29            0.070455
# 30            0.070455
# 31            0.040196
# 32                 NaN
# 33            0.218367
# 34            0.484211
# 35            0.075949
# 36            0.075949
# 37            0.075949
# 38            0.227642
# 39            0.000000
# 40            0.027027
# 41            0.027027
# 42            0.000000
# 43                 NaN
# 44            0.042218
# 45            0.042218
# 46            0.042218
# 47            0.063014
# 48                 NaN
# 49                 NaN
# 50                 NaN
# 51            0.789474
# 52            0.789474
# 53            0.039488
# 54            0.000000
# 55            0.000000
# 56            0.293030
# 57            0.293030
# 58            0.293030
# 59            0.052674
# 60            0.000000
# 61            0.000000
# 62            0.020056
# 63            0.000000
# 64            0.000000
# 65            0.000000
# 66            0.000000
# 67            0.000000
# 68                 NaN
# 69            0.000000
# 70            0.000000
# 71            0.000000
# 72            0.000000
# 73            0.000000
# 74            0.000000
# 75            0.000000
# 76            0.000000
# 77            0.000000
# 78            0.000000
# 79            0.000000
# 80            0.391304
# 81                 NaN
# 82            0.000000
# 83            0.000000
# 84            0.074818
# 85            0.314286
# 86            0.314286
# 87                 NaN
# 88                 NaN
# 89                 NaN
# 90                 NaN
# 91                 NaN
# 92                 NaN
# 93                 NaN
# 94                 NaN
# 95                 NaN
# 96                 NaN
# 97                 NaN
# 98                 NaN
# 99                 NaN
# ..                 ...
# 335           0.054443
# 336           0.311573
# 337           0.311573
# 338                NaN
# 339                NaN
# 340                NaN
# 341                NaN
# 342           0.000000
# 343           0.000000
# 344           0.000000
# 345           0.000000
# 346           0.119433
# 347           0.644444
# 348                NaN
# 349                NaN
# 350                NaN
# 351                NaN
# 352           0.128079
# 353           0.734940
# 354           0.070588
# 355           0.000000
# 356           0.000000
# 357           0.020860
# 358           0.413712
# 359           0.000000
# 360           0.000000
# 361           0.000000
# 362           0.000000
# 363           0.020161
# 364           0.126761
# 365           0.241758
# 366           0.000000
# 367           0.000000
# 368                NaN
# 369           0.607692
# 370                NaN
# 371           0.492308
# 372           0.492308
# 373           0.492308
# 374           0.000000
# 375           0.000000
# 376           0.000000
# 377           0.129800
# 378           0.971530
# 379           0.000000
# 380           0.020950
# 381                NaN
# 382                NaN
# 383                NaN
# 384           0.123894
# 385           0.123894
# 386           0.123894
# 387                NaN
# 388           0.000000
# 389           0.000000
# 390           0.010123
# 391           0.010123
# 392           0.010123
# 393           0.010123
# 394                NaN
# 395           0.061856
# 396                NaN
# 397           0.000000
# 398                NaN
# 399                NaN
# 400                NaN
# 401                NaN
# 402                NaN
# 403                NaN
# 404           0.078601
# 405           0.078601
# 406           0.000000
# 407                NaN
# 408           0.071856
# 409           0.071856
# 410           0.071856
# 411           0.071856
# 412           0.071856
# 413           0.071856
# 414           0.071856
# 415           0.036195
# 416           0.036195
# 417           0.036195
# 418           0.036195
# 419           0.000000
# 420           0.000000
# 421           0.104693
# 422           0.027434
# 423           0.063830
# 424                NaN
# 425           0.000000
# 426           0.000000
# 427           0.000000
# 428                NaN
# 429                NaN
# 430                NaN
# 431           0.175676
# 432           0.083333
# 433           0.048907
# 434                NaN
#
# [435 rows x 9 columns]

# %%
excluded3.shape
# Out:
# (435, 90)

# %%
# 4. There are total 22 records in excluded4
excluded4 = pd.merge(left = part_d, right = exclusions, how = 'inner', 
      left_on = ['nppes_provider_first_name','nppes_provider_last_org_name','nppes_provider_state'],
      right_on = ['FIRSTNAME','LASTNAME','STATE']
     )
excluded4[cols]
# Out:
#            npi nppes_provider_first_name nppes_provider_last_org_name  \
# 0   1013070861                   CHARLES                       HARRIS
# 1   1053349506                      JOSE                       TORRES
# 2   1144278052                    ROBERT                       TAYLOR
# 3   1144382672                      MARY                        SMITH
# 4   1184608903                    ROBERT                          LEE
# 5   1205807864                    ROBERT                         ROTH
# 6   1205839776                    MARTHA                     MARTINEZ
# 7   1275501629                    ROBERT                        JONES
# 8   1346213907                   STEPHEN                          LEE
# 9   1346223179                   RICHARD                        SMITH
# 10  1356315410                       DUC                       NGUYEN
# 11  1356408017                    ROBERT                     GONZALES
# 12  1427333186                   REBECCA                       MARTIN
# 13  1518012954                     DAVID                     WILLIAMS
# 14  1528326428                   WILLIAM                         LANE
# 15  1538442017                  JENNIFER                        ORTIZ
# 16  1659506111                   DESMOND                      FRANCIS
# 17  1700185345                      ALAN                         KATZ
# 18  1770505612                  HARRISON                         YANG
# 19  1871955906                    CARMEN                        LOPEZ
# 20  1942309596                 MARGARITA                    RODRIGUEZ
# 21  1942592324                  JENNIFER                        SMITH
#
#    nppes_provider_state         NPI  FIRSTNAME   LASTNAME STATE  \
# 0                    TX           0    CHARLES     HARRIS    TX
# 1                    FL           0       JOSE     TORRES    FL
# 2                    CA           0     ROBERT     TAYLOR    CA
# 3                    MS           0       MARY      SMITH    MS
# 4                    IL           0     ROBERT        LEE    IL
# 5                    CA  1700869864     ROBERT       ROTH    CA
# 6                    TX           0     MARTHA   MARTINEZ    TX
# 7                    CA           0     ROBERT      JONES    CA
# 8                    PA           0    STEPHEN        LEE    PA
# 9                    IL           0    RICHARD      SMITH    IL
# 10                   CA           0        DUC     NGUYEN    CA
# 11                   CA           0     ROBERT   GONZALES    CA
# 12                   TX           0    REBECCA     MARTIN    TX
# 13                   CA           0      DAVID   WILLIAMS    CA
# 14                   MA           0    WILLIAM       LANE    MA
# 15                   NY           0   JENNIFER      ORTIZ    NY
# 16                   NY  1659506111    DESMOND    FRANCIS    NY
# 17                   NY           0       ALAN       KATZ    NY
# 18                   TN  1770505612   HARRISON       YANG    TN
# 19                   FL           0     CARMEN      LOPEZ    FL
# 20                   FL           0  MARGARITA  RODRIGUEZ    FL
# 21                   NC           0   JENNIFER      SMITH    NC
#
#     opioid_claim_rate
# 0            0.000000
# 1            0.040196
# 2            0.000000
# 3            0.000000
# 4            0.172285
# 5                 NaN
# 6                 NaN
# 7            0.034858
# 8            0.000000
# 9            0.000000
# 10           0.727273
# 11           0.000000
# 12           0.000000
# 13           0.281746
# 14           0.261905
# 15           0.000000
# 16           0.089926
# 17           0.000000
# 18           0.119433
# 19           0.000000
# 20                NaN
# 21           0.036195

# %%
excluded4.shape
# Out:
# (22, 90)
